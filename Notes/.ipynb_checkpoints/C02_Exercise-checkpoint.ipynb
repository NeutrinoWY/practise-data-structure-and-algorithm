# %%
"""
Write a Python class, Flower, that has three instance variables of type str, int, and float, 
that respectively represent the name of the flower, its number of petals, and its price. 
Your class must include a constructor method that initializes each variable to an appropriate value, 
and your class should include methods for setting the value of each type, and retrieving the value of each type.
"""
class Flower:
    
    def __init__(self,name,num,price):
        self._name = name
        self._num = num
        self._price = price
    
    def getname(self):
        return self._name
    
    def getpetaln(self):
        return self._num
    
    def getprice(self):
        return self._price
    
    def setname(self,newname):
        self._name = newname
    
    def setprice(self, newprice):
        self._price = newprice

if __name__ == "__main__":
    
    sunf = Flower("sunflower", 6, 2)
    a = sunf.getname()
    sunf.setname("Big Sunflower")
    b = sunf.getname()
    c = sunf.getpetaln()
    sunf.setprice(10)
    d = sunf.getprice()
    print("original name:", a,"\n", "New name:", b,"\n", "number of Petals:", c,"\n", "Price:", d)
# Out:
# original name: sunflower
#  New name: Big Sunflower
#  number of Petals: 6
#  Price: 10
# 0.002368927001953125
